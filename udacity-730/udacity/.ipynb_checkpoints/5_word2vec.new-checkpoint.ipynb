# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /Users/rolf/anaconda2/envs/ml-py3.6/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.040865
# Nearest to or: releases, engraver, khans, jointly, goldie, oldham, satirists, strawberries,
# Nearest to two: soundtracks, abolishing, alford, pasha, randomized, gera, greek, identities,
# Nearest to their: watchful, comorian, breadth, cathodes, caribou, hawking, repeatable, fantastical,
# Nearest to more: dominating, veracity, soaemias, robots, heterosexual, endure, nicknames, coffey,
# Nearest to after: manipulating, tarot, sitcoms, bhp, conscripted, vocalic, andersen, interdiction,
# Nearest to is: cannibalism, ribosomes, rassemblement, vertigo, surfers, tsars, baltimore, leutze,
# Nearest to often: reassignment, guzman, virtuous, gl, bloodless, fsf, noi, beuve,
# Nearest to not: seedless, canto, brainfuck, tofu, sheryl, propto, endocrinology, lyceum,
# Nearest to the: factors, sip, tremblay, factions, potion, golems, murdoc, archdiocese,
# Nearest to during: freya, bird, kissing, offense, smiley, gravesite, eck, hbo,
# Nearest to world: orloff, craig, hump, solutes, faded, redness, quasars, grbac,
# Nearest to his: altarpiece, marches, kampaku, snakes, microchip, fit, crochet, natively,
# Nearest to had: gal, kd, varanus, yar, hellene, capricious, reinhardt, redesignated,
# Nearest to on: nobleman, kx, kildall, yamato, blacklist, vehicular, lash, broadcast,
# Nearest to has: ekaterina, term, clears, crete, workmen, homophonic, innovative, meteorite,
# Nearest to most: legionnaires, records, lifespans, pie, corpus, unusually, assesses, herg,
# Average loss at step 2000: 4.368655
# Average loss at step 4000: 3.864449
# Average loss at step 6000: 3.785740
# Average loss at step 8000: 3.689810
# Average loss at step 10000: 3.618745
# Nearest to or: and, brunswick, unequivocal, molly, apologize, uriah, while, lvaro,
# Nearest to two: three, four, five, seven, eight, nine, six, zero,
# Nearest to their: his, its, breadth, any, andres, ludo, truman, antihydrogen,
# Nearest to more: mahayana, very, elements, altruists, dominating, bitten, soaemias, judgment,
# Nearest to after: manipulating, ablaut, unnecessarily, conscripted, ewald, jacobson, administering, hysteresis,
# Nearest to is: was, are, has, hy, be, talleyrand, includes, were,
# Nearest to often: sometimes, generally, follow, reassignment, mbta, there, combined, irony,
# Nearest to not: we, they, it, also, still, who, to, there,
# Nearest to the: a, this, his, an, its, gardiner, guyana, estudios,
# Nearest to during: bird, freya, atom, at, ambitious, hbo, on, eck,
# Nearest to world: orloff, middle, hilltops, naur, craig, tombs, ideas, allan,
# Nearest to his: their, s, the, its, passengers, her, marches, any,
# Nearest to had: has, have, was, gal, industrialists, did, reinhardt, flickering,
# Nearest to on: in, at, from, blacklist, nobleman, simulators, and, polynesia,
# Nearest to has: had, was, is, have, symbolic, alves, ekaterina, kashmir,
# Nearest to most: records, taker, pie, oxford, unusually, sheet, uzbekistan, fridays,
# Average loss at step 12000: 3.603534
# Average loss at step 14000: 3.570230
# Average loss at step 16000: 3.413581
# Average loss at step 18000: 3.460840
# Average loss at step 20000: 3.538827
# Nearest to or: and, than, molly, lackey, leveling, repeat, luton, vf,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to their: his, its, the, breadth, her, any, some, andres,
# Nearest to more: less, very, most, mahayana, beattie, altruists, soaemias, bitten,
# Nearest to after: when, before, manipulating, lu, ordinated, from, binary, within,
# Nearest to is: was, has, are, were, be, adverse, allegorical, but,
# Nearest to often: sometimes, generally, also, now, there, mbta, currently, follow,
# Nearest to not: still, they, also, it, now, we, never, be,
# Nearest to the: their, its, his, estudios, this, a, any, casualties,
# Nearest to during: in, bird, at, through, freya, when, from, atom,
# Nearest to world: middle, craig, ideas, tombs, silas, orloff, wisconsin, amyotrophic,
# Nearest to his: their, its, her, the, passengers, litas, this, template,
# Nearest to had: has, have, was, were, gal, did, industrialists, been,
# Nearest to on: at, in, upon, nobleman, heeled, eftpos, kx, from,
# Nearest to has: had, was, have, is, nil, mauretania, forever, explains,
# Nearest to most: some, more, use, less, records, taker, many, expansions,
# Average loss at step 22000: 3.506704
# Average loss at step 24000: 3.491495
# Average loss at step 26000: 3.478433
# Average loss at step 28000: 3.483375
# Average loss at step 30000: 3.500996
# Nearest to or: and, than, purportedly, molly, exponential, luton, mala, advertisements,
# Nearest to two: three, four, one, five, six, seven, eight, zero,
# Nearest to their: its, his, the, her, any, breadth, some, denominations,
# Nearest to more: less, very, most, mahayana, rather, altruists, greater, flattery,
# Nearest to after: before, when, during, in, since, from, ordinated, last,
# Nearest to is: was, has, are, includes, be, tab, but, were,
# Nearest to often: sometimes, generally, usually, also, currently, commonly, now, still,
# Nearest to not: they, still, we, it, never, you, there, now,
# Nearest to the: their, its, his, a, estudios, gardiner, lakeland, embellishments,
# Nearest to during: in, after, when, bird, at, from, through, until,
# Nearest to world: match, ideas, silas, middle, craig, null, wisconsin, sow,
# Nearest to his: their, her, its, the, s, bluntly, litas, your,
# Nearest to had: has, have, was, were, when, having, did, bouvines,
# Nearest to on: in, upon, eftpos, from, nobleman, blacklist, into, at,
# Nearest to has: had, have, is, was, allows, forever, explains, fugues,
# Nearest to most: many, more, some, less, use, records, taker, navigable,
# Average loss at step 32000: 3.502807
# Average loss at step 34000: 3.495391
# Average loss at step 36000: 3.455613
# Average loss at step 38000: 3.298751
# Average loss at step 40000: 3.433074
# Nearest to or: and, than, purportedly, sped, indies, sarti, advertisements, a,
# Nearest to two: three, six, four, five, seven, eight, nine, one,
# Nearest to their: its, his, her, breadth, your, the, any, some,
# Nearest to more: less, most, very, greater, mahayana, flattery, fairly, rather,
# Nearest to after: before, when, during, since, from, ordinated, johan, upon,
# Nearest to is: was, has, be, are, hy, app, finlandization, interviewer,
# Nearest to often: sometimes, generally, usually, still, commonly, also, there, now,
# Nearest to not: never, still, they, it, you, usually, often, generally,
# Nearest to the: a, this, its, his, their, each, any, cilicia,
# Nearest to during: at, after, when, before, in, through, against, until,
# Nearest to world: amyotrophic, match, solving, silas, methuen, divider, null, tamara,
# Nearest to his: their, her, its, the, your, delson, my, teenagers,
# Nearest to had: has, have, was, were, having, did, been, never,
# Nearest to on: upon, eftpos, blacklist, in, kx, simulators, with, nobleman,
# Nearest to has: had, have, was, is, explains, greeted, sts, neuroscientist,
# Nearest to most: more, some, less, many, taker, expansions, records, uzbekistan,
# Average loss at step 42000: 3.436369
# Average loss at step 44000: 3.455506
# Average loss at step 46000: 3.454802
# Average loss at step 48000: 3.357966
# Average loss at step 50000: 3.387044
# Nearest to or: and, than, metrication, sped, purportedly, gmbh, aerobatic, like,
# Nearest to two: three, one, six, four, eight, seven, five, nine,
# Nearest to their: its, his, her, the, breadth, your, my, our,
# Nearest to more: less, most, very, rather, better, larger, fairly, flattery,
# Nearest to after: before, when, during, since, ordinated, following, cowardice, upon,
# Nearest to is: was, has, are, tab, includes, stirner, leone, although,
# Nearest to often: sometimes, generally, usually, commonly, now, typically, still, also,
# Nearest to not: never, they, still, generally, now, mjt, we, who,
# Nearest to the: its, their, this, his, a, some, any, washes,
# Nearest to during: in, after, when, at, before, against, through, under,
# Nearest to world: amyotrophic, match, conservatorium, capture, civil, methuen, indic, tuscan,
# Nearest to his: their, her, its, my, your, him, the, them,
# Nearest to had: has, have, was, having, were, did, been, industrialists,
# Nearest to on: upon, in, at, eftpos, eighteen, capricious, kx, blacklist,
# Nearest to has: had, have, is, was, concordia, silent, explains, includes,
# Nearest to most: more, less, many, some, use, navigable, uzbekistan, dough,
# Average loss at step 52000: 3.436187
# Average loss at step 54000: 3.427531
# Average loss at step 56000: 3.437979
# Average loss at step 58000: 3.396253
# Average loss at step 60000: 3.395927
# Nearest to or: and, than, purportedly, sped, like, plummeted, rectum, non,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to their: its, his, her, your, the, my, whose, our,
# Nearest to more: less, very, most, fairly, larger, mahayana, rather, longer,
# Nearest to after: before, during, when, following, despite, without, since, schawlow,
# Nearest to is: was, are, has, includes, although, remains, seems, does,
# Nearest to often: sometimes, usually, generally, commonly, typically, now, frequently, also,
# Nearest to not: still, never, generally, usually, they, you, now, who,
# Nearest to the: their, its, a, any, this, his, conspiratorial, some,
# Nearest to during: after, before, when, in, although, at, until, under,
# Nearest to world: amyotrophic, finances, amazons, sow, unpowered, bebop, tamara, conservatorium,
# Nearest to his: her, their, its, my, your, the, our, louis,
# Nearest to had: has, have, was, were, having, did, never, could,
# Nearest to on: upon, through, eftpos, in, blacklist, kx, during, ensuing,
# Nearest to has: had, have, was, is, includes, previously, having, concordia,
# Nearest to most: many, some, more, use, less, uzbekistan, all, taker,
# Average loss at step 62000: 3.241423
# Average loss at step 64000: 3.258101
# Average loss at step 66000: 3.399817
# Average loss at step 68000: 3.400871
# Average loss at step 70000: 3.357511
# Nearest to or: and, than, any, like, plummeted, sarti, objectivist, sped,
# Nearest to two: three, four, six, one, seven, five, eight, dogg,
# Nearest to their: its, his, her, your, the, our, these, my,
# Nearest to more: less, most, very, larger, rather, fairly, longer, fewer,
# Nearest to after: before, during, when, following, administering, without, upon, while,
# Nearest to is: was, has, are, be, does, remains, contains, includes,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, still,
# Nearest to not: still, never, generally, now, usually, they, simply, we,
# Nearest to the: their, its, a, any, this, another, these, some,
# Nearest to during: after, before, in, at, when, until, through, despite,
# Nearest to world: bwv, unpowered, amazons, finances, country, amyotrophic, silas, ii,
# Nearest to his: her, their, its, my, your, marches, delson, the,
# Nearest to had: has, have, was, were, having, never, did, joual,
# Nearest to on: upon, through, in, within, eftpos, northerly, regimens, inheriting,
# Nearest to has: had, have, is, was, protectorate, concordia, contains, explains,
# Nearest to most: more, less, many, use, some, all, especially, uzbekistan,
# Average loss at step 72000: 3.375501
# Average loss at step 74000: 3.347774
# Average loss at step 76000: 3.316925
# Average loss at step 78000: 3.354627
# Average loss at step 80000: 3.381022
# Nearest to or: and, than, while, unequivocal, adolf, sverdlovsk, but, cmi,
# Nearest to two: three, six, five, four, seven, one, eight, zero,
# Nearest to their: its, his, her, your, our, my, the, themselves,
# Nearest to more: less, very, most, fairly, larger, rather, fewer, longer,
# Nearest to after: before, during, when, following, despite, while, without, upon,
# Nearest to is: was, has, includes, contains, are, involves, became, becomes,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, still,
# Nearest to not: still, never, generally, they, usually, we, you, actually,
# Nearest to the: its, their, this, a, his, acculturation, depot, ferrand,
# Nearest to during: after, in, before, when, at, until, despite, from,
# Nearest to world: unpowered, bwv, amazons, country, rewriting, silas, finances, twin,
# Nearest to his: her, their, its, my, your, our, delson, the,
# Nearest to had: has, have, was, were, having, never, did, saw,
# Nearest to on: upon, in, through, blacklist, during, at, dugout, eftpos,
# Nearest to has: had, have, is, was, yitzhak, includes, contains, explains,
# Nearest to most: more, some, less, many, especially, uzbekistan, use, among,
# Average loss at step 82000: 3.408386
# Average loss at step 84000: 3.409603
# Average loss at step 86000: 3.390854
# Average loss at step 88000: 3.359573
# Average loss at step 90000: 3.363708
# Nearest to or: and, though, fibres, sized, rectum, inexpensively, asanga, while,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to their: his, its, her, your, our, my, outreach, the,
# Nearest to more: less, very, most, fairly, rather, fewer, larger, quite,
# Nearest to after: before, during, when, following, without, while, despite, until,
# Nearest to is: was, has, are, be, contains, includes, although, involves,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, also, still,
# Nearest to not: still, never, we, generally, they, you, now, only,
# Nearest to the: its, this, his, their, each, a, our, any,
# Nearest to during: after, in, before, when, through, at, despite, until,
# Nearest to world: country, unpowered, match, rewriting, maidstone, donating, europe, amazons,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to had: has, have, having, was, were, did, been, dihedral,
# Nearest to on: upon, through, blacklist, under, nobleman, capricious, around, blockading,
# Nearest to has: had, have, is, was, having, contains, includes, yitzhak,
# Nearest to most: more, many, some, less, use, especially, uzbekistan, dough,
# Average loss at step 92000: 3.395546
# Average loss at step 94000: 3.250941
# Average loss at step 96000: 3.356964
# Average loss at step 98000: 3.240529
# Average loss at step 100000: 3.357661
# Nearest to or: and, than, plummeted, vs, frankel, while, without, heian,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to their: its, his, her, your, our, the, several, my,
# Nearest to more: less, very, most, fairly, rather, larger, greater, fewer,
# Nearest to after: before, during, without, when, following, despite, while, upon,
# Nearest to is: was, has, are, became, becomes, be, includes, remains,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, still, now,
# Nearest to not: never, still, generally, they, you, only, encloses, now,
# Nearest to the: his, their, its, a, your, this, ferrand, our,
# Nearest to during: after, in, before, throughout, through, despite, when, within,
# Nearest to world: country, unpowered, maidstone, match, silas, psychopathic, universe, midcourse,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to had: has, have, was, having, received, were, glacial, since,
# Nearest to on: upon, through, at, in, within, under, eftpos, via,
# Nearest to has: had, have, is, was, since, explains, having, involves,
# Nearest to most: more, less, some, especially, use, many, uzbekistan, both,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
